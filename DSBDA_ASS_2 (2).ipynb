# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df
# Out:
#      gender  math score  reading score  writing score  placement score  \
# 0   female         63.0           84.0             64             84.0
# 1    female        71.0           80.0             76             86.0
# 2    female        64.0           81.0             66             81.0
# 3     male         71.0           85.0             77             96.0
# 4     male         68.0           86.0             76              NaN
# 5    female        94.0           86.0             61            100.0
# 6     male         75.0           79.0             66            -99.0
# 7    female         NaN            NaN             66             95.0
# 8     male         66.0           88.0             66             88.0
# 9     male         70.0           79.0             61             87.0
# 10   female       -99.0           80.0             65             85.0
# 11    male         76.0           84.0            -99              NaN
# 12   female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df.isnull()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0    False       False          False          False            False
# 1    False       False          False          False            False
# 2    False       False          False          False            False
# 3    False       False          False          False            False
# 4    False       False          False          False             True
# 5    False       False          False          False            False
# 6    False       False          False          False            False
# 7    False        True           True          False            False
# 8    False       False          False          False            False
# 9    False       False          False          False            False
# 10   False       False          False          False            False
# 11   False       False          False          False             True
# 12   False       False          False          False            False
#
#     club join year  placemnet offer
# 0            False            False
# 1            False            False
# 2            False            False
# 3            False            False
# 4            False            False
# 5            False            False
# 6            False            False
# 7            False            False
# 8            False            False
# 9            False            False
# 10           False            False
# 11           False            False
# 12           False            False

# %%
series = pd.isnull(df["reading score"])
df[series]
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 7  female         NaN            NaN             66             95.0
#
#    club join year  placemnet offer
# 7            2019                3

# %%
df.notnull()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     True        True           True           True             True
# 1     True        True           True           True             True
# 2     True        True           True           True             True
# 3     True        True           True           True             True
# 4     True        True           True           True            False
# 5     True        True           True           True             True
# 6     True        True           True           True             True
# 7     True       False          False           True             True
# 8     True        True           True           True             True
# 9     True        True           True           True             True
# 10    True        True           True           True             True
# 11    True        True           True           True            False
# 12    True        True           True           True             True
#
#     club join year  placemnet offer
# 0             True             True
# 1             True             True
# 2             True             True
# 3             True             True
# 4             True             True
# 5             True             True
# 6             True             True
# 7             True             True
# 8             True             True
# 9             True             True
# 10            True             True
# 11            True             True
# 12            True             True

# %%
seseries = pd.notnull(df["reading score"])
df[series]
# Out:
#    gender  math score  reading score  writing score  placement score  \
# 7  female         NaN            NaN             66             95.0
#
#    club join year  placemnet offer
# 7            2019                3

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder ()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1        63.0           84.0             64             84.0
# 1        0        71.0           80.0             76             86.0
# 2        0        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 4        2        68.0           86.0             76              NaN
# 5        0        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 7        0         NaN            NaN             66             95.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10       0       -99.0           80.0             65             85.0
# 11       2        76.0           84.0            -99              NaN
# 12       0        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder ()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0        1        63.0           84.0             64             84.0
# 1        0        71.0           80.0             76             86.0
# 2        0        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 4        2        68.0           86.0             76              NaN
# 5        0        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 7        0         NaN            NaN             66             95.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10       0       -99.0           80.0             65             85.0
# 11       2        76.0           84.0            -99              NaN
# 12       0        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df['gender'].replace({1: "male", 0: "female"}, inplace=True)
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 4        2        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 7   female         NaN            NaN             66             95.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11       2        76.0           84.0            -99              NaN
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf=df
ndf.fillna(0)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 4        2        68.0           86.0             76              0.0
# 5   female        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 7   female         0.0            0.0             66             95.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11       2        76.0           84.0            -99              0.0
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
m_v=df['reading score'].mean()
df['reading score'].fillna(value=m_v, inplace=True)
df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3        2        71.0      85.000000             77             96.0
# 4        2        68.0      86.000000             76              NaN
# 5   female        94.0      86.000000             61            100.0
# 6        2        75.0      79.000000             66            -99.0
# 7   female         NaN      82.583333             66             95.0
# 8        2        66.0      88.000000             66             88.0
# 9        2        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11       2        76.0      84.000000            -99              NaN
# 12  female        74.0      79.000000             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3        2        71.0      85.000000             77             96.0
# 4        2        68.0      86.000000             76            -99.0
# 5   female        94.0      86.000000             61            100.0
# 6        2        75.0      79.000000             66            -99.0
# 7   female       -99.0      82.583333             66             95.0
# 8        2        66.0      88.000000             66             88.0
# 9        2        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11       2        76.0      84.000000            -99            -99.0
# 12  female        74.0      79.000000             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.dropna()
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 5   female        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 5             2019                1
# 6             2020                1
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 12            2019                2

# %%
ndf.dropna(how = 'all')
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0      84.000000             64             84.0
# 1   female        71.0      80.000000             76             86.0
# 2   female        64.0      81.000000             66             81.0
# 3        2        71.0      85.000000             77             96.0
# 4        2        68.0      86.000000             76              NaN
# 5   female        94.0      86.000000             61            100.0
# 6        2        75.0      79.000000             66            -99.0
# 7   female         NaN      82.583333             66             95.0
# 8        2        66.0      88.000000             66             88.0
# 9        2        70.0      79.000000             61             87.0
# 10  female       -99.0      80.000000             65             85.0
# 11       2        76.0      84.000000            -99              NaN
# 12  female        74.0      79.000000             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
ndf.dropna(axis = 1)
# Out:
#     gender  reading score  writing score  club join year  placemnet offer
# 0     male      84.000000             64            2020                2
# 1   female      80.000000             76            2018                3
# 2   female      81.000000             66            2020                3
# 3        2      85.000000             77            2018                1
# 4        2      86.000000             76            2021                3
# 5   female      86.000000             61            2019                1
# 6        2      79.000000             66            2020                1
# 7   female      82.583333             66            2019                3
# 8        2      88.000000             66            2020                3
# 9        2      79.000000             61            2021                2
# 10  female      80.000000             65            2021                1
# 11       2      84.000000            -99            2020                2
# 12  female      79.000000             79            2019                2

# %%
new_data =ndf.dropna (axis = 0, how ='any')
new_data
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 5   female        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 5             2019                1
# 6             2020                1
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 12            2019                2

# %%
col =['reading score', 'reading score', 'writing score', 'placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['reading score']>90))
print(np.where(df['writing score']>90))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
fig, ax =plt.subplots(figsize = (18,10))
ax.scatter(df['reading score'], df['writing score'])
plt.show()
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['reading score']<50) & (df['writing score']>1)))
print(np.where((df['reading score']>85) & (df['writing score']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
z = np.abs(stats.zscore(df['reading score']))

# %%
print(z)
# Out:
# 0     0.472390
# 1     0.861418
# 2     0.527966
# 3     0.805843
# 4     1.139295
# 5     1.139295
# 6     1.194870
# 7     0.000000
# 8     1.806199
# 9     1.194870
# 10    0.861418
# 11    0.472390
# 12    1.194870
# Name: reading score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([7], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [79.0,
#  79.0,
#  79.0,
#  80.0,
#  80.0,
#  81.0,
#  82.58333333333333,
#  84.0,
#  84.0,
#  85.0,
#  86.0,
#  86.0,
#  88.0]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 80.0 85.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 72.5 92.5

# %%
new_df=df
for i in sample_outliers:new_df.drop(i,inplace=True)
new_df
# Out:
#     gender  math score  reading score  writing score  placement score  \
# 0     male        63.0           84.0             64             84.0
# 1   female        71.0           80.0             76             86.0
# 2   female        64.0           81.0             66             81.0
# 3        2        71.0           85.0             77             96.0
# 4        2        68.0           86.0             76              NaN
# 5   female        94.0           86.0             61            100.0
# 6        2        75.0           79.0             66            -99.0
# 8        2        66.0           88.0             66             88.0
# 9        2        70.0           79.0             61             87.0
# 10  female       -99.0           80.0             65             85.0
# 11       2        76.0           84.0            -99              NaN
# 12  female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['reading score'], 90)
b = np.where(df_stud['reading score']>ninetieth_percentile,
ninetieth_percentile, df_stud['reading score'])
print("New array:",b)
# Out:
# New array: [84. 80. 81. 85. 86. 86. 79. nan 88. 79. 80. 84. 79.]

# %%
col = ['reading score']

df.boxplot(col)
# Out:
# <Axes: >

# %%
median=np.median(sorted_rscore)
median
# Out:
# 82.58333333333333

# %%
refined_df=df
refined_df['reading score'] = np.where(refined_df['reading score'] >upr_bound, median,refined_df['reading score'])

# %%
df
# Out:
#      gender  math score  reading score  writing score  placement score  \
# 0   female         63.0           84.0             64             84.0
# 1    female        71.0           80.0             76             86.0
# 2    female        64.0           81.0             66             81.0
# 3     male         71.0           85.0             77             96.0
# 4     male         68.0           86.0             76              NaN
# 5    female        94.0           86.0             61            100.0
# 6     male         75.0           79.0             66            -99.0
# 7    female         NaN            NaN             66             95.0
# 8     male         66.0           88.0             66             88.0
# 9     male         70.0           79.0             61             87.0
# 10   female       -99.0           80.0             65             85.0
# 11    male         76.0           84.0            -99              NaN
# 12   female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
refined_df['reading score'] = np.where(refined_df['reading score'] <lwr_bound, median,refined_df['reading score'])

# %%
df
# Out:
#      gender  math score  reading score  writing score  placement score  \
# 0   female         63.0           84.0             64             84.0
# 1    female        71.0           80.0             76             86.0
# 2    female        64.0           81.0             66             81.0
# 3     male         71.0           85.0             77             96.0
# 4     male         68.0           86.0             76              NaN
# 5    female        94.0           86.0             61            100.0
# 6     male         75.0           79.0             66            -99.0
# 7    female         NaN            NaN             66             95.0
# 8     male         66.0           88.0             66             88.0
# 9     male         70.0           79.0             61             87.0
# 10   female       -99.0           80.0             65             85.0
# 11    male         76.0           84.0            -99              NaN
# 12   female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
col = ['reading score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
df
# Out:
#      gender  math score  reading score  writing score  placement score  \
# 0   female         63.0           84.0             64             84.0
# 1    female        71.0           80.0             76             86.0
# 2    female        64.0           81.0             66             81.0
# 3     male         71.0           85.0             77             96.0
# 4     male         68.0           86.0             76              NaN
# 5    female        94.0           86.0             61            100.0
# 6     male         75.0           79.0             66            -99.0
# 7    female         NaN            NaN             66             95.0
# 8     male         66.0           88.0             66             88.0
# 9     male         70.0           79.0             61             87.0
# 10   female       -99.0           80.0             65             85.0
# 11    male         76.0           84.0            -99              NaN
# 12   female        74.0           79.0             79             98.0
#
#     club join year  placemnet offer
# 0             2020                2
# 1             2018                3
# 2             2020                3
# 3             2018                1
# 4             2021                3
# 5             2019                1
# 6             2020                1
# 7             2019                3
# 8             2020                3
# 9             2021                2
# 10            2021                1
# 11            2020                2
# 12            2019                2

# %%
import matplotlib.pyplot as plt
new_df['reading score'].plot(kind ='hist')
df['log_math'] = np.log10(df['reading score'])

# %%
df['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>
